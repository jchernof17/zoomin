# %%
import networkx as nx
from parse import read_input_file, read_output_file
import matplotlib.pyplot as plt
file = "small-10"
G = read_input_file("inputs/" + file + ".in")
T = read_output_file("outputs/" + file + ".out",G)
nx.draw(G)
plt.draw()

# %%
nx.draw(T)

plt.draw()
